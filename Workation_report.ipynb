# %% [markdown]
# # Workation

# %% [markdown]
# To do reproducible research we used project from unsupervised machine learning course. The code is written in R, and our aim is to translate it to Python. We will reproduce the results and discuss findings, any potential problems and provide some conclusion.

# %% [markdown]
# ### The project was to cluster workation (work + vacation) data and compare the clusters with given ranking.

# %%
# Load the libraries
import pandas as pd
from sklearn.preprocessing import StandardScaler
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
from sklearn.decomposition import PCA
from sklearn.cluster import KMeans
from sklearn_extra.cluster import KMedoids
from sklearn.metrics import silhouette_score
from mlxtend.plotting import plot_pca_correlation_graph
from IPython.display import display
from numpy.random import uniform
from codes.helpers import hopkins_statistic
import random

# %%
# Load the data from working directory
raw_data = pd.read_csv("workation.csv", sep=';')

# %% [markdown]
# ### To set your working directory, use the below code

# %%
# import os
# print os.getcwd() # Print the current working directory
# os.chdir('c:\\Users\\uname\\desktop\\python')  # Provide the new path here

# %% [markdown]
# ## EDA

# %%
# Preview the data
display(raw_data.head())
display(raw_data.describe())
# Out:
#    Ranking          City    Country
# 0        1       Bangkok   Thailand  \
# 1        2     New Delhi      India
# 2        3        Lisbon   Portugal
# 3        4     Barcelona      Spain
# 4        5  Buenos Aires  Argentina
#
#    Remote connection: Average WiFi speed (Mbps per second)
# 0                                                 28        \
# 1                                                 12
# 2                                                 33
# 3                                                 37
# 4                                                 17
#
#    Co-working spaces: Number of co-working spaces
# 0                                             117  \
# 1                                             165
# 2                                              95
# 3                                             136
# 4                                              67
#
#    Caffeine: Average price of buying a coffee
# 0                                        1.56  \
# 1                                        1.42
# 2                                        1.56
# 3                                        1.59
# 4                                        1.22
#
#    Travel: Average price of taxi (per km)
# 0                                    0.82  \
# 1                                    0.19
# 2                                    0.40
# 3                                    1.01
# 4                                    0.47
#
#    After-work drinks: Average price for 2 beers in a bar
# 0                                               3.08      \
# 1                                               2.90
# 2                                               3.42
# 3                                               5.12
# 4                                               2.16
#
#    Accommodation: Average price of 1 bedroom apartment per month
# 0                                             415.18              \
# 1                                             179.25
# 2                                             736.19
# 3                                             768.46
# 4                                             229.55
#
#    Food: Average cost of a meal at a local, mid-level restaurant
# 0                                               1.54              \
# 1                                               2.90
# 2                                               7.69
# 3                                              10.25
# 4                                               5.15
#
#    Climate: Average number of sunshine hours
# 0                                       2624  \
# 1                                       2685
# 2                                       2806
# 3                                       2591
# 4                                       2525
#
#    Tourist attractions: Number of ‘Things to do’ on Tripadvisor
# 0                                               2262             \
# 1                                               2019
# 2                                               1969
# 3                                               2739
# 4                                               1660
#
#    Instagramability: Number of photos with #
# 0                                   28386616
# 1                                   28528249
# 2                                   10205538
# 3                                   62894055
# 4                                   21293975
#           Ranking  Remote connection: Average WiFi speed (Mbps per second)
# count  147.000000                                         147.000000        \
# mean    73.938776                                          26.823129
# std     42.602210                                          16.386889
# min      1.000000                                           2.000000
# 25%     37.500000                                          14.500000
# 50%     74.000000                                          25.000000
# 75%    110.500000                                          34.500000
# max    147.000000                                          93.000000
#
#        Co-working spaces: Number of co-working spaces
# count                                      147.000000  \
# mean                                        48.435374
# std                                         50.320897
# min                                          0.000000
# 25%                                         13.000000
# 50%                                         33.000000
# 75%                                         65.500000
# max                                        318.000000
#
#        Caffeine: Average price of buying a coffee
# count                                  147.000000  \
# mean                                     2.279796
# std                                      0.875517
# min                                      0.830000
# 25%                                      1.565000
# 50%                                      2.340000
# 75%                                      2.865000
# max                                      6.100000
#
#        Travel: Average price of taxi (per km)
# count                              147.000000  \
# mean                                 1.005442
# std                                  0.561604
# min                                  0.150000
# 25%                                  0.545000
# 50%                                  0.940000
# 75%                                  1.310000
# max                                  3.000000
#
#        After-work drinks: Average price for 2 beers in a bar
# count                                         147.000000      \
# mean                                            6.204150
# std                                             3.561373
# min                                             1.080000
# 25%                                             3.340000
# 50%                                             5.740000
# 75%                                             8.570000
# max                                            17.800000
#
#        Accommodation: Average price of 1 bedroom apartment per month
# count                                         147.000000              \
# mean                                          719.551020
# std                                           424.714931
# min                                            83.020000
# 25%                                           370.315000
# 50%                                           642.770000
# 75%                                           933.220000
# max                                          2171.680000
#
#        Food: Average cost of a meal at a local, mid-level restaurant
# count                                         147.000000              \
# mean                                            8.158639
# std                                             4.382837
# min                                             1.250000
# 25%                                             4.800000
# 50%                                             8.520000
# 75%                                            11.495000
# max                                            19.760000
#
#        Climate: Average number of sunshine hours
# count                                 147.000000  \
# mean                                 2409.619048
# std                                   662.858446
# min                                  1203.000000
# 25%                                  1863.000000
# 50%                                  2468.000000
# 75%                                  2897.000000
# max                                  3940.000000
#
#        Tourist attractions: Number of ‘Things to do’ on Tripadvisor
# count                                         147.000000             \
# mean                                         1042.891156
# std                                          1139.228765
# min                                            70.000000
# 25%                                           457.500000
# 50%                                           741.000000
# 75%                                          1336.500000
# max                                         10269.000000
#
#        Instagramability: Number of photos with #
# count                               1.470000e+02
# mean                                1.883580e+07
# std                                 2.573515e+07
# min                                 4.094700e+05
# 25%                                 4.376657e+06
# 50%                                 9.950961e+06
# 75%                                 2.151362e+07
# max                                 1.507026e+08

# %% [markdown]
# ### Rename columns for easier use

# %%
# Rename columns
raw_data.rename(columns={
    'Remote connection: Average WiFi speed (Mbps per second)': 'WiFi',
    'Co-working spaces: Number of co-working spaces': 'CoWorking',
    'Caffeine: Average price of buying a coffee': 'Coffee',
    'Travel: Average price of taxi (per km)': 'Taxi',
    'After-work drinks: Average price for 2 beers in a bar': 'Beer',
    'Accommodation: Average price of 1 bedroom apartment per month': 'Accommodation',
    'Food: Average cost of a meal at a local, mid-level restaurant': 'Food',
    'Climate: Average number of sunshine hours': 'Sunshine',
    'Tourist attractions: Number of ‘Things to do’ on Tripadvisor': 'Attractions',
    'Instagramability: Number of photos with #': 'Instagram'
}, inplace=True)

raw_data.head(3)
# Out:
#    Ranking       City   Country  WiFi  CoWorking  Coffee  Taxi  Beer
# 0        1    Bangkok  Thailand    28        117    1.56  0.82  3.08  \
# 1        2  New Delhi     India    12        165    1.42  0.19  2.90
# 2        3     Lisbon  Portugal    33         95    1.56  0.40  3.42
#
#    Accommodation  Food  Sunshine  Attractions  Instagram
# 0         415.18  1.54      2624         2262   28386616
# 1         179.25  2.90      2685         2019   28528249
# 2         736.19  7.69      2806         1969   10205538

# %%
#Remove ranking, city and country from the dataset as they are not informative
data = raw_data.loc[:, 'WiFi':'Instagram']

# %%
# Check for NAs:
print(data.isna().any()) # no NAs
# Out:
# WiFi             False
# CoWorking        False
# Coffee           False
# Taxi             False
# Beer             False
# Accommodation    False
# Food             False
# Sunshine         False
# Attractions      False
# Instagram        False
# dtype: bool

# %% [markdown]
# ### Create a boxplot for every variable

# %%
# Boxplots
red_circle = dict(markerfacecolor='red', marker='o', markeredgecolor='white')
fig, axs = plt.subplots(2, 5, figsize=(20, 10))

for i, ax in enumerate(axs.flat):
    ax.boxplot(data.iloc[:, i], flierprops=red_circle)
    ax.set_title(data.columns[i], fontsize=20, fontweight='bold')
    ax.tick_params(axis='y', labelsize=14)

plt.tight_layout()

# %% [markdown]
# ### Plot correlation matrix

# %%
# Correlation
corr_data = data.corr()

f, ax = plt.subplots(figsize=(10, 8))
sns.heatmap(corr_data,
    cmap=sns.color_palette("vlag", 10, as_cmap=True),
    vmin=-1.0, vmax=1.0,
    square=True, ax=ax)
# Out:
# <AxesSubplot: >

# %% [markdown]
# ### Normalize the data

# %%
# Normalize the data
scaler = StandardScaler()
data_s = pd.DataFrame(scaler.fit_transform(data), columns=data.columns)

# %% [markdown]
# ## PCA

# %%
# Perform PCA for all 10 components
pca = PCA(n_components=10)

# Fit and transform the data
pca.fit_transform(data_s)
# Out:
# array([[-1.08032559,  2.24079427, -0.20132302, ..., -0.0427179 ,
#         -0.53817195, -0.57496978],
#        [-1.72681301,  2.97660956,  0.3106337 , ..., -1.05372492,
#         -0.05432882, -0.95085998],
#        [-0.61464475,  1.30361118,  0.09439809, ..., -0.96544909,
#          0.11441867, -0.21858914],
#        ...,
#        [ 3.81786475, -2.84818547, -0.68522873, ..., -0.44805594,
#         -0.11041616,  0.31941946],
#        [ 0.86680341, -2.39379738,  0.24096913, ..., -0.64363569,
#          0.55883517,  0.08849166],
#        [ 2.63144286, -2.34384193, -0.85771711, ...,  0.23301724,
#         -0.83755006,  0.11560643]])

# %% [markdown]
# ### Plots

# %%
# create a bar plot
plt.bar(
    range(1, len(pca.explained_variance_ratio_) + 1),
    pca.explained_variance_ratio_,
    label='percentage of explained variance', align='center'
)
plt.xlabel('PCA Feature')
plt.ylabel('Explained variance')
plt.title('Feature Explained Variance')
plt.legend(loc='best')
plt.show()


# Plot correlation circle for first two dimensions
figure, correlation_matrix = plot_pca_correlation_graph(data_s,
                                                        data.columns,
                                                        dimensions=(1, 2, 3 ),
                                                        figure_axis_size=10)

# create bar plot for first dimension
plt.bar(
    range(1,10+1),
    -np.sort(-np.abs(correlation_matrix['Dim 1']/np.sum(np.abs(correlation_matrix['Dim 1'])))),
    label='individual explained variance',  align='center'
    )

# create bar plot for second dimension
plt.bar(
    range(1,10+1),
    -np.sort(-np.abs(correlation_matrix['Dim 2']/np.sum(np.abs(correlation_matrix['Dim 2'])))),
    label='individual explained variance',  align='center'
    )

# create bar plot for third dimension
plt.bar(
    range(1,10+1),
    -np.sort(-np.abs(correlation_matrix['Dim 3']/np.sum(np.abs(correlation_matrix['Dim 2'])))),
    label='individual explained variance',  align='center'
    )
# Out:
# <BarContainer object of 10 artists>

# %%
# Print eigenvalues
display(pca.explained_variance_)

# create data for PCA
data_ = pca.transform(data_s)
data_pca = data_[:, 0:3]
data_pca = pd.DataFrame(data_pca)

# Calculate the hopkins statistics
print(hopkins_statistic(data_pca))
# Out:
# array([3.96855553, 2.19317279, 1.21956437, 0.79001913, 0.5272226 ,
#        0.41539829, 0.34376494, 0.24265639, 0.22026267, 0.14787645])
# 0.7519758728584622

# %% [markdown]
# ## Clustering

# %%
# Prepare data for clustering
data_pca = np.array(data_pca)

# %% [markdown]
# ### Silhouette score

# %%
# Check Silhouette values

# define random seed
seed_ = 3

range_n_clusters = [2, 3, 4, 5, 6, 7, 8, 9, 10]
silhouette_avg = []
for num_clusters in range_n_clusters:
    # perform kmeans
    kmeans = KMeans(n_clusters=num_clusters, n_init='auto', random_state=seed_)
    kmeans.fit(data_pca)
    cluster_labels = kmeans.labels_
    
        # calculate silhouette score
    silhouette_avg.append(silhouette_score(data_pca, cluster_labels))
    
plt.plot(range_n_clusters, silhouette_avg, 'bx-')
plt.xlabel('Values of K')
plt.ylabel('Silhouette score')
plt.title('Silhouette analysis For Optimal k')
plt.show()
# Out:
# C:\Users\Rodzinka\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:1382: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# C:\Users\Rodzinka\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:1382: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# C:\Users\Rodzinka\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:1382: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# C:\Users\Rodzinka\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:1382: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# C:\Users\Rodzinka\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:1382: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# C:\Users\Rodzinka\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:1382: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# C:\Users\Rodzinka\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:1382: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# C:\Users\Rodzinka\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:1382: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# C:\Users\Rodzinka\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:1382: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(

# %% [markdown]
# ### Elbow method

# %%
range_n_clusters = [2, 3, 4, 5, 6, 7, 8, 9, 10]
distortions = []
for num_clusters in range_n_clusters:
    # initialise kmeans
    kmeans = KMeans(n_clusters=num_clusters, n_init='auto', random_state = seed_)
    kmeans.fit(data_pca)
    cluster_labels = kmeans.labels_

    # silhouette score
    distortions.append(kmeans.inertia_)

plt.plot(range_n_clusters, distortions, 'bx-')
plt.xlabel('Clusters')
plt.ylabel('Variance explained')
plt.title('Elbow method')
plt.show()
# Out:
# C:\Users\Rodzinka\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:1382: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# C:\Users\Rodzinka\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:1382: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# C:\Users\Rodzinka\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:1382: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# C:\Users\Rodzinka\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:1382: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# C:\Users\Rodzinka\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:1382: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# C:\Users\Rodzinka\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:1382: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# C:\Users\Rodzinka\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:1382: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# C:\Users\Rodzinka\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:1382: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# C:\Users\Rodzinka\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:1382: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(

# %% [markdown]
# ### Kmedoids 3 clusters (PAM)

# %%
# Perform PAM on chosen number of clusters
pam = KMedoids(n_clusters = 3).fit(data_pca)

# Save labels in a separate object
labels = pam.labels_

# %% [markdown]
# ### Plot clusters

# %%
# Plot data split into clusters
unique_labels = set(labels)
colors = [plt.cm.Spectral(each) for each in np.linspace(0, 1, len(unique_labels))]

for k, col in zip(unique_labels, colors):
    class_member_mask = labels == k
    xy = data_pca[class_member_mask]
    plt.plot(
        xy[:, 0],
        xy[:, 1],
        "o",
        markerfacecolor=tuple(col),
        markeredgecolor="k",
        markersize=6)

plt.plot(
    pam.cluster_centers_[:, 0],
    pam.cluster_centers_[:, 1],
    "o",
    markerfacecolor="cyan",
    markeredgecolor="k",
    markersize=6,
    label="Medoids")

plt.legend(loc='best')
plt.title("CLusters obtained using PAM")
# Out:
# Text(0.5, 1.0, 'CLusters obtained using PAM')

# %% [markdown]
# ### Display clusters

# %%
# Append labels to original dataset
raw_data['Assigned_label'] = labels

# Data for first cluster
display(raw_data[raw_data['Assigned_label']==0])

# Data for second cluster
display(raw_data[raw_data['Assigned_label']==1])

# Data for third cluster
display(raw_data[raw_data['Assigned_label']==2])
# Out:
#      Ranking          City     Country  WiFi  CoWorking  Coffee  Taxi  Beer
# 0          1       Bangkok    Thailand    28        117    1.56  0.82  3.08  \
# 1          2     New Delhi       India    12        165    1.42  0.19  2.90
# 2          3        Lisbon    Portugal    33         95    1.56  0.40  3.42
# 4          5  Buenos Aires   Argentina    17         67    1.22  0.47  2.16
# 5          5      Budapest     Hungary    37         40    1.20  0.72  2.40
# ..       ...           ...         ...   ...        ...     ...   ...   ...
# 112      113          Hvar     Croatia    19          0    1.57  0.85  8.54
# 114      115      San Jose  Costa Rica    10         17    1.72  0.75  3.48
# 120      121     Vientiane        Laos     5          3    1.64  1.43  1.64
# 129      130        La Paz     Bolivia     6          7    1.91  1.14  3.34
# 134      135         Dakar     Senegal     6          6    2.00  1.30  1.64
#
#      Accommodation   Food  Sunshine  Attractions  Instagram  Assigned_label
# 0           415.18   1.54      2624         2262   28386616               0
# 1           179.25   2.90      2685         2019   28528249               0
# 2           736.19   7.69      2806         1969   10205538               0
# 4           229.55   5.15      2525         1660   21293975               0
# 5           366.66   4.81      1988         1468   14267880               0
# ..             ...    ...       ...          ...        ...             ...
# 112         179.32  12.81      3535           85     880583               0
# 114         417.08   5.21      2081          305    5084798               0
# 120         366.07   2.51      3250          104     409470               0
# 129         257.89   2.61      2289          211    1451813               0
# 134         502.94   3.91      3078           70    2108284               0
#
# [65 rows x 14 columns]
#      Ranking               City         Country  WiFi  CoWorking  Coffee
# 57        58               Faro        Portugal    70          1    1.57  \
# 58        59              Osaka           Japan    26         47    2.33
# 64        65           Montreal          Canada    27         60    2.37
# 70        71          Ljubljana        Slovenia    61          8    1.45
# 72        73           Florence           Italy    18         13    1.12
# 74        75          Liverpool  United Kingdom    26         17    2.66
# 77        77            Tallinn         Estonia    37         14    2.43
# 81        82              Kyoto           Japan    29          9    3.05
# 92        93           Brussels         Belgium    37         66    2.60
# 96        97               Lyon          France    36         21    2.65
# 97        98  Palma de Mallorca           Spain    29         15    1.81
# 98        99           Brisbane       Australia    22         37    2.49
# 107      108            Calgary          Canada    24         34    2.44
# 108      109              Perth       Australia    19         29    2.45
# 109      110          Marseille          France    24         11    2.29
# 110      111            Cologne         Germany    33         38    2.34
# 113      114         Dusseldorf         Germany    25         44    2.59
# 116      117           Helsinki         Finland    36         22    3.38
# 117      118           Adelaide       Australia    18         17    2.34
# 118      119           Bordeaux          France    20         14    2.67
# 119      120          Frankfurt         Germany    22         66    2.49
# 121      122          Stuttgart         Germany    33         25    2.51
# 122      123           Hannover         Germany    38          7    2.26
# 124      125           Edmonton          Canada    30         10    2.69
# 125      126            Dresden         Germany    35          5    2.04
# 127      128          Rotterdam     Netherlands    37         31    2.52
# 128      129     St. Petersburg          Russia    21          4    2.41
# 131      132             Ottawa          Canada    26         24    2.59
# 133      134          Edinburgh  United Kingdom    26         23    2.76
# 135      136          Dubrovnik         Croatia    19          0    2.52
# 136      137             Muscat            Oman     8          7    3.47
# 138      139            Glasgow  United Kingdom    26         16    2.77
# 139      140            Belfast  United Kingdom    26         13    2.74
# 140      141        Kuwait City          Kuwait     7          4    3.56
# 141      142           Salzburg         Austria    30          7    2.68
# 145      146           Valletta           Malta    10          1    2.33
#
#      Taxi   Beer  Accommodation   Food  Sunshine  Attractions  Instagram
# 57   0.85   4.24         509.68   7.43      3036          167    1705160  \
# 58   2.61   2.93         621.08   5.21      1996          790   16057725
# 64   1.01   6.94         737.69   8.67      2051          793   18833685
# 70   0.85   4.44         527.62   8.54      1974          422    1737701
# 72   0.85   8.54         650.53  12.81      2924         1377   10392587
# 74   0.93   3.50         649.17  12.00      2199         1050   14834860
# 77   0.51   6.82         466.50   8.52      1923          490    2861931
# 81   1.19   4.76         612.23   5.21      1775         1533   17684174
# 92   1.66   6.84         724.37  12.81      1546          747    7074355
# 96   1.51   5.24         596.38  10.89      2002          502    9144123
# 97   0.83   4.26         736.96  12.77      2763          446    2370407
# 98   1.17   8.62         929.46  10.78      2968          668   11948455
# 107  1.16   8.10         722.32  10.40      2396          540    7317582
# 108  0.91   9.54         803.84  10.60      3230          416   10684382
# 109  1.29  10.24         514.68  11.10      2858          488    8058438
# 110  1.71   6.84         711.60   8.11      1504          465    7660853
# 113  1.88   6.84         685.86   8.54      2359          312    7242509
# 116  0.85  10.24         860.76  11.10      1858          624    7238202
# 117  1.08   6.36         783.36   8.63      2765          458    6427748
# 118  1.42  10.24         601.71  11.10      2713          560    7924124
# 119  1.71   6.84         894.56   8.54      1586          497   11611541
# 121  1.45   6.82         800.83  10.22      1692          250    9950961
# 122  1.71   5.98         526.02   8.54      1501          177    4633789
# 124  1.04   6.94         681.29  11.56      2345          294    4765517
# 125  1.87   5.94         447.61   8.49      1581          303    3640354
# 127  1.71   6.80        1016.10  12.74      1745          323    6749161
# 128  1.00   5.74         995.39   8.96      1636         3218    3030245
# 131  1.15   8.06         928.07  11.52      2084          435    6914271
# 133  1.42   8.50         808.33  15.00      1427         1163    9582024
# 135  1.19   9.12         578.51  11.95      3322          468    2556696
# 136  0.51  14.96         448.11   4.67      3493          219    3433459
# 138  1.06   7.00         651.23  15.00      1203          682    7250566
# 139  1.07   9.00         604.91  11.98      1868          483    3389741
# 140  1.38   4.78         643.09   4.79      3940          132    4133614
# 141  1.65   6.64         655.73  10.64      1697          290    3108680
# 145  2.55   6.10         890.99  17.03      3054          144     764698
#
#      Assigned_label
# 57                1
# 58                1
# 64                1
# 70                1
# 72                1
# 74                1
# 77                1
# 81                1
# 92                1
# 96                1
# 97                1
# 98                1
# 107               1
# 108               1
# 109               1
# 110               1
# 113               1
# 116               1
# 117               1
# 118               1
# 119               1
# 121               1
# 122               1
# 124               1
# 125               1
# 127               1
# 128               1
# 131               1
# 133               1
# 135               1
# 136               1
# 138               1
# 139               1
# 140               1
# 141               1
# 145               1
#      Ranking           City               Country  WiFi  CoWorking  Coffee
# 3          4      Barcelona                 Spain    37        136    1.59  \
# 11        12         Madrid                 Spain    32        125    1.70
# 21        22      Singapore             Singapore    93        117    2.95
# 29        30    Los Angeles         United States    58        105    3.39
# 32        33      Hong Kong             Hong Kong    78        183    3.50
# 35        36      Las Vegas         United States    47         21    3.36
# 37        38  San Francisco         United States    75         77    3.39
# 38        38         Berlin               Germany    33        127    2.49
# 39        40      San Diego         United States    74         53    3.06
# 40        41          Tokyo                 Japan    32        163    2.65
# 41        42        Chicago         United States    42        104    3.02
# 43        44         Vienna               Austria    42         91    2.82
# 44        45       New York         United States    37        272    3.48
# 47        48          Dubai  United Arab Emirates    15        115    3.66
# 49        50        Houston         United States    60         62    2.80
# 51        52          Miami         United States    40         59    3.25
# 52        53         Sydney             Australia    28         93    2.14
# 54        55      Melbourne             Australia    21        127    2.34
# 56        57           Rome                 Italy    17         50    1.07
# 62        63        Phoenix         United States    44         35    3.32
# 68        69          Paris                France    30        136    3.17
# 69        70        Toronto                Canada    26        113    2.63
# 75        76    New Orleans         United States    45         16    3.25
# 76        77  Washington DC         United States    68         59    3.30
# 82        83        Hamburg               Germany    41         65    2.46
# 84        85      Vancouver                Canada    40         43    2.60
# 85        86          Milan                 Italy    17         87    1.38
# 88        89       Portland         United States    44         31    3.04
# 94        95         Dublin               Ireland    61         46    2.88
# 99       100       Auckland           New Zealand    34         30    2.57
# 101      101         London        United Kingdom    22        318    2.95
# 102      103      Stockholm                Sweden    37         50    3.35
# 104      105       Honolulu                Hawaii    43          8    4.05
# 105      105         Munich               Germany    31         87    2.70
# 106      107         Boston         United States    33         41    3.20
# 111      112      Amsterdam           Netherlands    22         99    2.85
# 115      116      Abu Dhabi  United Arab Emirates     9         32    3.48
# 123      124     Copenhagen               Denmark    46         26    4.46
# 126      126     Manchester        United Kingdom    33         38    2.81
# 130      131           Doha                 Qatar    12         13    3.39
# 132      133       Tel Aviv                Israel    14         28    3.02
# 137      138           Oslo                Norway    49         33    3.62
# 142      143         Beirut               Lebanon     4         18    6.10
# 143      144         Zurich           Switzerland    33         42    3.97
# 144      145         Geneva           Switzerland    36         23    3.52
# 146      147      Reykjavik               Iceland    26          9    3.36
#
#      Taxi   Beer  Accommodation   Food  Sunshine  Attractions  Instagram
# 3    1.01   5.12         768.46  10.25      2591         2739   62894055  \
# 11   0.94  10.02         751.80  10.25      2769         1976   44165754
# 21   0.48   9.54        1455.77   7.28      2022         1561   41453533
# 29   1.21  10.08        1612.62  14.40      3254         1375   75436810
# 32   0.79  10.12        1581.43   5.56      1836         1330   39815830
# 35   1.45   8.64         826.39  10.80      3825         1420   40524360
# 37   1.34  10.08        2149.04  14.34      3062         1490   30781286
# 38   1.71   4.98         810.65   8.54      1626         1894   48461817
# 39   1.34   8.60        1553.79  10.75      3055         1118   29887093
# 40   2.75   6.54        1011.57   6.55      1881         3416   56623159
# 41   1.21   7.92        1330.55  12.24      2508         1411   51603607
# 43   1.21   6.82         755.00   9.37      1930         1149   14453386
# 44   1.34  10.58        2171.68  14.40      2535        10269  113711319
# 47   0.43  17.64        1069.88   6.86      3885         1615  110962610
# 49   1.03   7.20        1002.84  10.80      2578          589   27197101
# 51   1.16   8.64        1400.80  11.52      3154          762   80497499
# 52   1.25   8.48        1398.15   9.54      2636         1343   33859310
# 54   0.87  10.78         925.10  10.78      2636         1242   33945108
# 56   1.02   8.52         822.90  12.77      2473         3444   27665299
# 62   1.00   7.18         936.98  10.78      3872          389    9833747
# 68   1.28  10.64        1054.23  12.77      1662         4265  130025724
# 69   1.15   8.06        1135.92  11.52      2066         1048   50157783
# 75   1.54   5.02        1002.56  12.51      2649         1016   11614267
# 76   1.87   8.60        1666.66  10.75      2528          778   10770923
# 82   1.63   7.26         809.13  10.25      1557          688   20155361
# 84   1.08   8.06        1166.84  11.52      1938          729   24259344
# 85   1.15   8.24         927.31  12.81      1915         1543   21733273
# 88   1.16   8.60        1151.21  11.47      2341          741   12325674
# 94   1.28   9.40        1437.05  12.81      1453         1243   12936240
# 99   1.32  10.06         964.17  10.06      2003         1099    5385894
# 101  1.70  10.00        1662.25  15.00      1633         4983  150702588
# 102  1.13  11.72        1154.07  10.05      1803          557   13630429
# 104  1.47   8.62        1368.17  10.78      3036          946    4898654
# 105  1.71   6.84        1115.58  11.95      1709          735   12132597
# 106  1.34  10.08        1877.31  14.40      2634          653   23846477
# 111  2.01   8.54        1316.79  12.81      1662         1782   33774833
# 115  0.39  15.68         891.43   5.88      3509          317   31532015
# 123  1.38  11.48        1178.93  14.92      1803          772   10101675
# 126  1.22   8.00         849.23  15.00      1416          458   16470240
# 130  0.40  17.80        1119.45   5.93      3897          203   22179935
# 132  0.88  13.28        1148.13  14.38      3311          757    6474622
# 137  1.16  14.94        1103.16  14.91      1668          444    8115873
# 142  1.02   9.50         735.51  19.10      3534          188   10239115
# 143  3.00  11.06        1541.47  19.76      1566          485    6904776
# 144  2.44  12.58        1565.45  19.67      1828          300    4329235
# 146  2.03  13.88        1170.60  14.46      1326          629    2057729
#
#      Assigned_label
# 3                 2
# 11                2
# 21                2
# 29                2
# 32                2
# 35                2
# 37                2
# 38                2
# 39                2
# 40                2
# 41                2
# 43                2
# 44                2
# 47                2
# 49                2
# 51                2
# 52                2
# 54                2
# 56                2
# 62                2
# 68                2
# 69                2
# 75                2
# 76                2
# 82                2
# 84                2
# 85                2
# 88                2
# 94                2
# 99                2
# 101               2
# 102               2
# 104               2
# 105               2
# 106               2
# 111               2
# 115               2
# 123               2
# 126               2
# 130               2
# 132               2
# 137               2
# 142               2
# 143               2
# 144               2
# 146               2

# %% [markdown]
# ## Reproducible research R vs Python comparison

# %% [markdown]
# The R code includes the file path for loading the data ("/Users/nataliamiela/Documents/master/UL/clustering project/workation.csv"). Although this specific path may be specific to the author's machine, it provides a clear indication of where the data should be located. However, this path would need to be modified to match the file location on the replicator's machine.
# As an improvement, we load the data directly from working directory. We added an instruction how to check your working directory and how to use a new path.
#
# For PCA, explained variance expressed in percentages was pretty much identical as in R. Additionally, correlation circle plot shows that the same variables are the most important, and have the same influence on dimensions 1 and 2.
# Calculated Hopkins statistic turned out to be significantly lower: 0.75 compared to 0.95 in R. This might be caused by the ranomness and the differences in random seed that was used in Python and R, as Hopkins statistics relies on drawing the uniform random samples from original data.
# Based on both  silhouette and variance explained plots we have decided to divide data into three clusters, while results obtained in R suggest that two clusters are optimal. We believe this is again caused by the lack of the properly defined random seed, which makes it impossible to replicate the result.
#
# Compared to R, Python lacks the proper libraries and/or functions to perform such analysis compared to R. What can be easily done in R using ready-to-use functions, is quite cumbersome in Python - for instance creating a circle plot for correlations or calculating the Hopkins statistics, where we had to resort to custom made function. On the other hand, data cleaning and preprocessing is more convenient to perform in Python. In conclusion, due to the lack of predefined random seeds and slightly different implementation of functions used for clustering and PCA in Python and R, we have obtained slightly different results.
